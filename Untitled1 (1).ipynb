# %%
#data type in python
#basic (integer,float,complex,boolean and string)
#container type( list, tuples,sets and dictonary)
# user defined type (class)

# %%
#integer
print(4)
print(1e310)
# Out:
# 4
# inf

# %%
#float
print(4.5)
print(1.7e308)
# Out:
# 4.5
# 1.7e+308

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#complex
print(4+5j)
# Out:
# (4+5j)

# %%
#string
print('kolkata')
print("kolkata")
print("""kolkata""")
# Out:
# kolkata
# kolkata
# kolkata

# %%
#container 
#list that means we call it array in diffent language
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictonary
print(
