# %%
#variables
#c lang
# int a = 5;

# %%
name = 'Nitish'
print(name)
# Out:
# Nitish

# %%
name ='Hello world'
print(name)
# Out:
# Hello world

# %%
# no variable declertaion

# %%
#dynamic typing in pyhton 
#static typing specify type of vairble but in pyhton there is no static typing only dynamic typing in php also same

# %%
print(name)
# Out:
# Hello world

# %%
name = 4
print(name)
# Out:
# 4

# %%
name = True
print(name)
# Out:
# True

# %%
#dynamic binding feature a vauriable takes multiple data type

# %%
#static binding

# %%
#special syntax 
a= 5; b=6; c=7
print(a)
print(b)
print(c)
# Out:
# 5
# 6
# 7

# %%
a,b,c= 4,5,6
print(a)
print(b)
print(c)
# Out:
# 4
# 5
# 6

# %%
a=b=c 
print(a)
print(b)
print(c)
